# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/summayashaikh079-stack/flyrank-ml-week1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
import os, subprocess
if not os.path.isdir("flyrank-ml-week1"):
    subprocess.run(["git", "clone", "--depth", "1", "https://github.com/summayashaikh079-stack/flyrank-ml-week1"], check=True)
os.chdir("flyrank-ml-week1")
print("Working dir:", os.getcwd())
# Out:
# Working dir: /content/flyrank-ml-week1/flyrank-ml-week1

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
"I'm choosing the Refresh / Content Opportunity Scoring lane. Many pages on a site lose traffic over time as content ages, but teams don't always know which pages to prioritize for refresh. This lane lets me rank pages by how much they'd benefit from an update, using signals I already explored in Week 1 (declining trend and content type performance)."
# Out:
# "I'm choosing the Refresh / Content Opportunity Scoring lane. Many pages on a site lose traffic over time as content ages, but teams don't always know which pages to prioritize for refresh. This lane lets me rank pages by how much they'd benefit from an update, using signals I already explored in Week 1 (declining trend and content type performance)."

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#Decision: Which content pages should the team refresh first?
#Unit of analysis: one page (one row per content item).
#Action: A content editor picks the top-ranked declining pages from my output and schedules them for refresh this sprint.
#Cost of a wrong call: If I flag a page that's actually stable, the team wastes editor time refreshing something that didn't need it. If I miss a genuinely declining high-value page, the site keeps losing traffic silently.
#Why ML/data can help: With hundreds of pages, no one can manually track trend + content type + engagement together — a ranked score turns scattered signals into one prioritized list

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

declining_pct = (df["trend_direction"].str.lower() == "down").mean() * 100
print(f"{declining_pct:.1f}% of pages are currently declining")

ctr_by_type = df.groupby("content_type")["ctr"].mean().sort_values()
print(ctr_by_type)
# Out:
# 54.2% of pages are currently declining
# content_type
# comparison article    0.131205
# keyword article       0.344766
# feedly article        2.791274
# Name: ctr, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#I can say this ranking shows which pages have declining or weak engagement signals right now — it is a prioritization tool, not proof that refreshing a page will fix it. I cannot claim this proves what caused the decline, and I should not treat the score as a guarantee of traffic recovery"

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
