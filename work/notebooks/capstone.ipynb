# %% [markdown]
# # Capstone — mirrors your deployed research paper
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/summayashaikh079-stack/flyrank-ml-week1/blob/main/work/notebooks/capstone.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Question
#
# *The research question and the decision it supports.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Data
#
# *Which release, which tables, date windows, what you excluded and why. Public-safe.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Methodology
#
# *Assumptions, features, label definition, baseline, validation design, leakage checks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Results (vs baseline)
#
# *Model vs baseline on the same split. The honest table.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Limitations
#
# *What this work cannot claim.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 6. Ranked recommendations
#
# *The action playbook output — the paper's recommendations section.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 7. Artifacts the paper embeds
#
# *Generate/collect the charts and tables your deployed page will show.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
# ## 8. Tell the Story — demo outline + shareable cuts
#
# ### 5-minute demo outline (Week-8 showcase, optional)
#
# 1. **Question (30s):** Can a Random Forest model rank FlyRank content pages by refresh priority better than a simple CTR-vs-position rule?
# 2. **Method (1 min):** Random Forest vs. a position-bucket CTR-gap rule, both scored on the same 30,000-row / 32-client sample, validated two ways — a naive random split and a client-grouped split.
# 3. **One chart (1.5 min):** the Precision@50 bar chart — 0.90 under the naive split, 0.54 under the honest client-grouped split, 0.51 base rate. Walk through why the grouped split is the one that matters (it mirrors scoring a client the model has never seen).
# 4. **One honest result (1 min):** under honest validation, the model shows no measured edge over the simple rule — both sit close to the base rate. The naive split's 0.90 was measuring client memorization, not generalization.
# 5. **One recommendation (1 min):** ship the rule-based, reason-coded queue (R1/R2/R3) today; keep a human in the loop; re-run monthly and watch for retrain triggers.
#
# ---
#
# ### Shareable cut 1 — social post (methodology)
#
# > Spent this internship testing whether a Random Forest model could out-rank a simple CTR-vs-position rule for flagging declining content, on FlyRank's real search-performance data.
# >
# > First pass looked great — 90% precision on my top 50 predictions. Then I re-ran the exact same model with one change: a client-grouped train/test split instead of a random one. Precision@50 fell to 54%, barely above the 51% base rate.
# >
# > Turns out the random split let the model see a bit of every client during training — so testing on "unseen" rows wasn't really testing on unseen *clients*. The grouped split is what actually matters if the model's job is to score a client it's never touched before.
# >
# > The honest number is less flattering, but it's the one I'd trust in production. Full writeup + charts: [paper link]
#
# ### Shareable cut 2 — employer-facing summary (3 sentences)
#
# I built a Random Forest classifier to rank FlyRank content pages by refresh priority, trained and evaluated on a 30,000-row sample of FlyRank's production search-performance data (79M-row warehouse) using scikit-learn. Under a naive random split it appeared to reach 90% precision on its top 50 predictions, but a client-grouped validation split — the honest test for scoring clients the model has never seen — showed no measured advantage over a simple rule-based baseline, both landing close to the 51% base rate. I shipped the honest result plus a reason-coded action playbook (three flag types, each with a specific next step) rather than overstating the model's readiness for production use.
